# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-3-haiku-20240307-latest"

# %%
# Helper functions
from anthropic.types import Message


def add_user_message(messages, message):
    user_message = {
        "role": "user",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(user_message)


def add_assistant_message(messages, message):
    assistant_message = {
        "role": "assistant",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[], tools=None):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if tools:
        params["tools"] = tools

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message


def text_from_message(message):
    return "\n".join(
        [block.text for block in message.content if block.type == "text"]
    )

# %%
web_search_schema = {
    "type": "web_search_20250305",
    "name": "web_search",
    "max_uses": 5,
    "allowed_domains": ["nih.gov"],
}

# %%
messages = []
add_user_message(
    messages,
    """
    What's the best exercise for gaining leg muscle? Dont generate too much text, just give me a short answer and cite a relevant webpage from nih.gov.
    """,
)
response = chat(messages, tools=[web_search_schema])
response
# Out:
# Message(id='msg_0199Jy2Em2ujzK67WVzpvaW3', content=[TextBlock(citations=None, text="I'll find information on the best exercises for leg muscle growth from a reputable source like NIH.", type='text'), ServerToolUseBlock(id='srvtoolu_01G5GhaiDQJUNF3h1K3aub35', input={'query': 'best exercises building leg muscle nih.gov'}, name='web_search', type='server_tool_use'), WebSearchToolResultBlock(content=[WebSearchResultBlock(encrypted_content='...', page_age=None, title='Three Types of Exercise Can Improve Your Health and Physical Ability | National Institute on Aging', type='web_search_result', url='https://www.nia.nih.gov/health/exercise-and-physical-activity/three-types-exercise-can-improve-your-health-and-physical'), WebSearchResultBlock(encrypted_content='...', page_age=None, title='Gluteus Maximus Activation during Common Strength and Hypertrophy Exercises: A Systematic Review - PMC', type='web_search_result', url='https://pmc.ncbi.nlm.nih.gov/articles/PMC7039033/'), WebSearchResultBlock(encrypted_content='...', page_age=None, title='Home-Based Leg Strengthening Exercise Improves Function One Year After Hip Fracture: A Randomized Controlled Study - PMC', type='web_search_result', url='https://pmc.ncbi.nlm.nih.gov/articles/PMC2956597/'), WebSearchResultBlock(encrypted_content='...', page_age=None, title='Evaluation of the Lower Limb Muscles’ Electromyographic Activity during the Leg Press Exercise and Its Variants: A Systematic Review - PMC', type='web_search_result', url='https://pmc.ncbi.nlm.nih.gov/articles/PMC7369968/'), WebSearchResultBlock(encrypted_content='...', page_age=None, title='Maximizing Muscle Hypertrophy: A Systematic Review of Advanced Resistance Training Techniques and Methods - PMC', type='web_search_result', url='https://pmc.ncbi.nlm.nih.gov/articles/PMC6950543/'), WebSearchResultBlock(encrypted_content='...', page_age=None, title='Muscle activity during leg strengthening exercise using free weights and elastic resistance: effects of ballistic vs controlled contractions - PubMed', type='web_search_result', url='https://pubmed.ncbi.nlm.nih.gov/23231756/'), WebSearchResultBlock(encrypted_content='', page_age=None, title='Nih', type='web_search_result', url='https://order.nia.nih.gov/sites/default/files/2021-02/exercise-physical-activity-get-fit4-life.pdf'), WebSearchResultBlock(encrypted_content='...', page_age=None, title='How can strength training build healthier bodies as we age? | National Institute on Aging', type='web_search_result', url='https://www.nia.nih.gov/news/how-can-strength-training-build-healthier-bodies-we-age'), WebSearchResultBlock(encrypted_content='...', page_age=None, title='The Impact of Back Squat and Leg-Press Exercises on Maximal Strength and Speed-Strength Parameters - PubMed', type='web_search_result', url='https://pubmed.ncbi.nlm.nih.gov/26439782/'), WebSearchResultBlock(encrypted_content='...', page_age=None, title='Four Types of Exercise Can Improve Your Health and Physical Ability | National Institute on Aging', type='web_search_result', url='https://www.nia.nih.gov/health/exercise-and-physical-activity/four-types-exercise-can-improve-your-health-and-physical')], tool_use_id='srvtoolu_01G5GhaiDQJUNF3h1K3aub35', type='web_search_tool_result'), TextBlock(citations=None, text='Based on the search results, I can provide you with information about the best exercises for gaining leg muscle.\n\n', type='text'), TextBlock(citations=[CitationsWebSearchResultLocation(cited_text='The exercises classified as very high level of GMax activation (>60% MVIC) were step-up, lateral step-up, diagonal step-up, cross over  ...
